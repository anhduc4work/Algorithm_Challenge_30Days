# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Solution

# %%
import time
start = time.time()

# %%
class Solution(object):
    def canBeIncreasing(self, nums):
        LENGTH = len(nums)
        remove_times = []
        count = 0
        # if LENGTH >= 3:
        #     for i in range(2,LENGTH, 2):
                
        #         a, b, c = nums[i-2], nums[i-1], nums[i]
        #         print(a,b,c)
        #         if a >= b and b >= c:
        #             return False
        #         else:
        #             a -= b 
        #             c -= b
        #             if a*c < 0:
        #                 pass
        #             else:   
        #                 if a>=0:
        #                     print(nums[i-2])
        #                 if c<= 0:
        #                     print(nums[i])
        if LENGTH ==2:
            if num[0] < num[1]:
                return True
            else:
                return False
        else:
            i == LENGTH
            while (i)

solution = Solution()

# %%
solution.canBeIncreasing([1,2,10,5,7])
# Out:
# 1 2 10
# 10 5 7
# 10

# %%
solution.canBeIncreasing([2,3,1,2])
# Out:
# 2 3 1
# 1

# %%
total = time.time() - start
print(f"Time taken: {total/60:.2f} mins")
# Out:
# Time taken: 21.26 mins

# %% [markdown]
# # Performance
