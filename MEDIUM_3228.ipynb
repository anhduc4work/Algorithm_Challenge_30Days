# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Solution

# %%
import time
start = time.time()

# %%
# Basic

class Solution(object):
    def maxOperations(self, s):
        count = 0
        save = []
        for _, digit in enumerate(s):
            if digit == '1':
                save.append(_)
        count_1 = len(save)

        if count_1 > 1:
            # if save[-1] < len(s)-1:  
            #     for i in range(count_1 - 1):
            #         if save[i] < save[i+1]-1:
            #             save[i] = save[i+1]-1
            #             count += 1
            #             print(save, 1)
            #     save[-1] = len(s)-1
            #     count += 1
            #     print(save, 2)
            pass
        elif count_1 == 1:
            if save[0] == len(s)-1:
                return 0
            else:
                return 1
        else: 
            return 0
        # print(save, count) 
        # while(save[0] < len(s)-len(save)):
        # print(save[0],save[-1],len(save))
        while(save[0] < save[-1]-len(save)+1):
        
            for i in range(count_1 - 1):
                if save[i] < save[i+1]-1:  
                    save[i] = save[i+1]-1
                    count += 1
                    # print(save, save[i], save[i+1])
                else: pass
        if save[-1] < len(s)-1: 
            return count + count_1
        else:
            return count
        
        # stop condition: the first '1' is index -n_count_1
        # 010010
        # 000101
        # 012345
        # save = [1,4]
        # till save[0] == 5-2

solution = Solution()

# %%
class Solution:
    def maxOperations(self, s: str) -> int:
        n = len(s)
        cnt = 0
        ans = 0
        i = 0
        while i < n:
            if s[i] == '0':
                ans += cnt
                while i < n and s[i] != '1':
                    i += 1
                print(i)
            cnt += 1
            i += 1
        return ans
solution = Solution()

# %%
solution.maxOperations('100110100')
# Out:
# 3
# 6
# 9
# 8

# %%
solution.maxOperations('00111')
# Out:
# 0

# %%
solution.maxOperations('001')
# Out:
# 0
